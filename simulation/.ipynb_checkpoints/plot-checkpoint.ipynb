# %%
import numpy as np

import pandas as pd
import os, json
path = os.getcwd() + '/summaries_part/'
jsons = os.listdir(path)


# dict_list = []
# for fname in jsons:
#     try:
#         with open(path + fname) as f:
#             dict_summary = json.load(f)
#             dict_list.append(dict_summary)
#     except:
#         continue

# df = pd.DataFrame(dict_list)

# with open(os.getcwd() + '/summary/all_summary.10.json', 'w', encoding = 'utf-8') as fout:
#     json.dump(dict_list, fout)
    
with open(os.getcwd() + '/summary/all_summary.10.json') as fout:
    dict_list = json.load(fout)
    
df = pd.DataFrame(dict_list)

# %%
measure_cat = {'adele.sparse', 'mrlasso.sparse'}
mtype = 'l2.'
measures = [mtype + _ for _ in measure_cat]
measures += ['eta']
agg_dict = dict()
for key in measures:
    agg_dict[key] = ['mean', 'std', 'count']
result = df.groupby(['m', 'n', 's', 'outlier.dist', 'eta.pre'], as_index=False).agg(agg_dict)
# Out:
#      m    n   s outlier.dist eta.pre l2.adele.sparse                  \
#                                                 mean       std count
# 0    4  200   5           15      -1        0.637740  0.104455    50
# 1    5   50   5           15      -1       13.642110  1.988399    50
# 2    5  100   5           15      -1        0.923333  0.446820    50
# 3    5  200   4           15      -1        0.480755  0.060369    50
# 4    5  200   5           15      -1        0.522615  0.077516    50
# 5    5  200   5           15       1        0.533330  0.063758    50
# 6    5  200   5           15       2        0.512850  0.072417    50
# 7    5  200   5           15       3        0.513392  0.095713    50
# 8    5  200   5           15       4        0.521533  0.078801    50
# 9    5  200   5           15       5        0.522649  0.071543    50
# 10   5  200   5           15       6        0.502489  0.054165    50
# 11   5  200   5           15       7        0.526182  0.084656    50
# 12   5  200   5           15       8        0.497170  0.066810    50
# 13   5  200   5           15       9        0.498476  0.069067    50
# 14   5  200   5           15      10        0.517248  0.084069    50
# 15   5  200   8           15      -1        0.535646  0.059382    50
# 16   5  200  16           15      -1        0.685986  0.114636    50
# 17   5  200  32           15      -1        4.400411  1.318357    50
# 18   5  200  64           15      -1       20.057812  1.032090    50
# 19   5  400   5           15      -1        0.356406  0.061529    50
# 20   5  800   5           15      -1        0.253135  0.052351    50
# 21   6  200   5           15      -1        0.428645  0.058934    50
# 22   9  200   5           15      -1        0.292283  0.036651    50
# 23  13  200   5           15      -1        0.200255  0.023046    50
# 24  20  200   5           15      -1        0.136194  0.020926    50
#
#    l2.mrlasso.sparse                     eta
#                 mean       std count    mean       std count
# 0           0.310542  0.060005    50   4.300  0.741757    50
# 1           4.430893  0.741393    50   4.192  2.106728    50
# 2           0.466970  0.198339    50   5.132  0.386211    50
# 3           0.206524  0.045893    50   5.018  0.937145    50
# 4           0.245437  0.052176    50   4.890  1.089139    50
# 5           0.990514  1.010491    50   1.000  0.000000    50
# 6           0.532790  0.743429    50   2.000  0.000000    50
# 7           0.248716  0.066755    50   3.000  0.000000    50
# 8           0.249713  0.048380    50   4.000  0.000000    50
# 9           0.324089  0.462876    50   5.000  0.000000    50
# 10          0.356829  0.578263    50   6.000  0.000000    50
# 11          0.289151  0.235583    50   7.000  0.000000    50
# 12          0.331709  0.472144    50   8.000  0.000000    50
# 13          2.973250  2.317672    50   9.000  0.000000    50
# 14          4.498816  0.607582    50  10.000  0.000000    50
# 15          0.311277  0.051630    50   5.064  1.074141    50
# 16          0.490011  0.093168    50   5.232  0.932506    50
# 17          3.903569  1.242206    50   4.702  1.340802    50
# 18         16.570995  0.702816    50   4.628  1.123958    50
# 19          0.171526  0.037922    50   5.086  0.941126    50
# 20          0.118534  0.034368    50   5.244  0.920550    50
# 21          0.202232  0.037781    50   5.786  0.556963    50
# 22          0.145280  0.026359    50   6.162  0.809860    50
# 23          0.098877  0.016508    50   6.224  1.146167    50
# 24          0.066358  0.012704    50   5.964  1.340996    50

# %%
from plot import get_plot2, get_plot, get_plot_threshold
fig, ax = get_plot(result, mtype)
fig.savefig(os.getcwd() + '/plots/' + mtype + 'sim.pdf')

# %%
fig, ax = get_plot_threshold(result, lower = 3, upper = 8, shade = True)
fig.savefig(os.getcwd() + '/plots/' + mtype + 'eta.pdf')

# %%
measure_cat = {'adele.sparse', 'mrlasso.sparse'}
mtype = 'error.'
measures = [mtype + _ for _ in measure_cat]
# for measure in measures:
#     df[measure] += - 0.5 ** 2 
agg_dict = dict()
for key in measures:
    agg_dict[key] = ['mean', 'std']
result = df.groupby(['m', 'n', 's', 'outlier.dist', 'eta.pre'], as_index=False).agg(agg_dict)

# %%
fig, ax = get_plot(result, mtype)
fig.savefig(os.getcwd() + '/plots/' + mtype + 'sim.pdf')
